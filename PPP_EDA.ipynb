# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
PPP_raw_df = pd.read_csv('./data/interim/PPP_concatenated.csv')
# Out:
# /home/dez/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (17,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
PPP_raw_df.head()
# Out:
#    Unnamed: 0    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0           0  3.509338e+09   01/22/2021            NaN              PPS
# 1           1  5.375618e+09   05/01/2020          101.0              PPP
# 2           2  9.677498e+09   05/01/2020          464.0              PPP
# 3           3  9.547168e+09   05/01/2020          464.0              PPP
# 4           4  8.885207e+09   04/28/2020            NaN              PPP
#
#                              BorrowerName          BorrowerAddress  \
# 0                             Exemption 6                      NaN
# 1                           NOT AVAILABLE                      NaN
# 2  NORTH CHARLESTON HOSPITALITY GROUP LLC      192 College Park Rd
# 3                    Q AND J SERVICES LLC  301 Old Georgetown Road
# 4                             Exemption 6                      NaN
#
#   BorrowerCity BorrowerState BorrowerZip  ...      Gender     Veteran  \
# ...

# %%
PPP_raw_df = PPP_raw_df.drop(PPP_raw_df.columns[-5:], axis=1)

# %%
PPP_raw_df.columns
# Out:
# Index(['Unnamed: 0', 'LoanNumber', 'DateApproved', 'SBAOfficeCode',
#        'ProcessingMethod', 'BorrowerName', 'BorrowerAddress', 'BorrowerCity',
#        'BorrowerState', 'BorrowerZip', 'LoanStatusDate', 'LoanStatus', 'Term',
#        'SBAGuarantyPercentage', 'InitialApprovalAmount',
#        'CurrentApprovalAmount', 'UndisbursedAmount', 'FranchiseName',
#        'ServicingLenderLocationID', 'ServicingLenderName',
#        'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState',
#        'ServicingLenderZip', 'RuralUrbanIndicator', 'HubzoneIndicator',
#        'LMIIndicator', 'BusinessAgeDescription', 'ProjectCity',
#        'ProjectCountyName', 'ProjectState', 'ProjectZip', 'CD', 'JobsReported',
#        'NAICSCode', 'Race', 'Ethnicity', 'UTILITIES_PROCEED',
#        'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED',
#        'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED',
# ...

# %%
PPP_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10560475 entries, 0 to 10560474
# Data columns (total 54 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Unnamed: 0                   int64
#  1   LoanNumber                   float64
#  2   DateApproved                 datetime64[ns]
#  3   SBAOfficeCode                float64
#  4   ProcessingMethod             object
#  5   BorrowerName                 object
#  6   BorrowerAddress              object
#  7   BorrowerCity                 object
#  8   BorrowerState                object
#  9   BorrowerZip                  object
#  10  LoanStatusDate               object
#  11  LoanStatus                   object
#  12  Term                         float64
#  13  SBAGuarantyPercentage        float64
#  14  InitialApprovalAmount        float64
#  15  CurrentApprovalAmount        float64
#  16  UndisbursedAmount            float64
#  17  FranchiseName                object
# ...

# %%
#converting DateApproved to datetime object
PPP_raw_df.DateApproved = pd.to_datetime(PPP_raw_df.DateApproved)

# %%
PPP_2020_df = PPP_raw_df[(PPP_raw_df.DateApproved >= "03-01-2020") & (PPP_raw_df.DateApproved <= "12-31-2020")]

# %%
PPP_2020_df.to_csv('./data/interim/PPP_filtered_2020.csv')
