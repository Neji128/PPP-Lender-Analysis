# %% [markdown]
# # 1.0 Data preparation

# %%
import numpy as np
import pandas as pd
import math
import base64

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Read the data file and take a look at the data
df = pd.read_csv('../data/raw/lender_data/lender_data.csv')
df.head()
# Out:
#    Unnamed: 0    RSSDHCR               OriginatingLender  \
# 0           0  1020395.0              CCB COMMUNITY BANK
# 1           1  1020582.0                  WOODTRUST BANK
# 2           2  1020667.0  NORTHWEST BANK & TRUST COMPANY
# 3           3  1020676.0     AMALGAMATED BANK OF CHICAGO
# 4           4  1020854.0           FIRSTBANK OF NEBRASKA
#
#   OriginatingLenderCity  OriginatingLenderLocationID OriginatingLenderState  \
# 0             ANDALUSIA                         26.0                     AL
# 1      WISCONSIN RAPIDS                      77051.0                     WI
# 2             DAVENPORT                      24824.0                     IA
# 3               CHICAGO                      20494.0                     IL
# 4                 WAHOO                      42693.0                     NE
#
#    CurrentApprovalAmount  ForgivenessAmount  ForgivnessPct  \
# 0            21420366.01        21224047.72       0.990835
# 1            31543689.32        31834545.84       1.009221
# 2            26963725.00        26824637.15       0.994842
# 3             3049177.89         3036048.99       0.995694
# 4            10426743.02        10401369.48       0.997566
#
#                       NAMEHCR   UNINUM  \
# 0      SOUTHERN NATIONAL CORP  10739.0
# 1    WOODTRUST FINANCIAL CORP   3599.0
# 2   NORTHWEST INVESTMENT CORP  10071.0
# 3  AMALGAMATED INVESTMENTS CO    581.0
# 4         BANK MANAGEMENT INC   3718.0
#
#                                               NM_LGL  \
# 0  SOUTHERN NATIONAL CORPORATION                 ...
# 1  WOODTRUST FINANCIAL CORPORATION               ...
# 2  NORTHWEST INVESTMENT CORP.                    ...
# 3  AMALGAMATED INVESTMENTS COMPANY               ...
# 4  BANK MANAGEMENT, INC.                         ...
#
#                          NM_SHORT     CERT
# 0  SOUTHERN NAT CORP               16595.0
# 1  WOODTRUST FC                     5335.0
# 2  NORTHWEST INV CORP              15830.0
# 3  AMALGAMATED INV CO                903.0
# 4  BANK MGMT                        5486.0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'RSSDHCR', 'OriginatingLender', 'OriginatingLenderCity',
#        'OriginatingLenderLocationID', 'OriginatingLenderState',
#        'CurrentApprovalAmount', 'ForgivenessAmount', 'ForgivnessPct',
#        'NAMEHCR', 'UNINUM', 'NM_LGL', 'NM_SHORT', 'CERT'],
#       dtype='object')

# %%
# Rename column names with underscores
columns_dict = {"RSSDHCR":"RSSDHCR",
               "OriginatingLender":"Originating_Lender",
               "OriginatingLenderCity":"Originating_Lender_City",
               "OriginatingLenderLocationID":"Originating_Lender_Location_ID",
               "OriginatingLenderState":"Originating_Lender_State",
               "OriginatingLenderLocationID":"Originating_Lender_Location_ID",
               "CurrentApprovalAmount":"Current_Approval_Amount",
               "ForgivenessAmount":"Forgiveness_Amount",
               "ForgivnessPct":"Forgivness_Pct",
               "NAMEHCR":"Name_HCR",
               "UNINUM":"UNINUM",
               "NM_LGL":"NM_LGL",
               "NM_SHORT":"NM_Short",               
               "CERT":"Cert"
              }
df = df.rename(columns=columns_dict)
df.columns
# Out:
# Index(['Unnamed: 0', 'RSSDHCR', 'Originating_Lender',
#        'Originating_Lender_City', 'Originating_Lender_Location_ID',
#        'Originating_Lender_State', 'Current_Approval_Amount',
#        'Forgiveness_Amount', 'Forgivness_Pct', 'Name_HCR', 'UNINUM', 'NM_LGL',
#        'NM_Short', 'Cert'],
#       dtype='object')

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
df.head()
# Out:
#      RSSDHCR              Originating_Lender Originating_Lender_City  \
# 0  1020395.0              CCB COMMUNITY BANK               ANDALUSIA
# 1  1020582.0                  WOODTRUST BANK        WISCONSIN RAPIDS
# 2  1020667.0  NORTHWEST BANK & TRUST COMPANY               DAVENPORT
# 3  1020676.0     AMALGAMATED BANK OF CHICAGO                 CHICAGO
# 4  1020854.0           FIRSTBANK OF NEBRASKA                   WAHOO
#
#    Originating_Lender_Location_ID Originating_Lender_State  \
# 0                            26.0                       AL
# 1                         77051.0                       WI
# 2                         24824.0                       IA
# 3                         20494.0                       IL
# 4                         42693.0                       NE
#
#    Current_Approval_Amount  Forgiveness_Amount  Forgivness_Pct  \
# 0              21420366.01         21224047.72        0.990835
# 1              31543689.32         31834545.84        1.009221
# 2              26963725.00         26824637.15        0.994842
# 3               3049177.89          3036048.99        0.995694
# 4              10426743.02         10401369.48        0.997566
#
#                      Name_HCR   UNINUM  \
# 0      SOUTHERN NATIONAL CORP  10739.0
# 1    WOODTRUST FINANCIAL CORP   3599.0
# 2   NORTHWEST INVESTMENT CORP  10071.0
# 3  AMALGAMATED INVESTMENTS CO    581.0
# 4         BANK MANAGEMENT INC   3718.0
#
#                                               NM_LGL  \
# 0  SOUTHERN NATIONAL CORPORATION                 ...
# 1  WOODTRUST FINANCIAL CORPORATION               ...
# 2  NORTHWEST INVESTMENT CORP.                    ...
# 3  AMALGAMATED INVESTMENTS COMPANY               ...
# 4  BANK MANAGEMENT, INC.                         ...
#
#                          NM_Short     Cert
# 0  SOUTHERN NAT CORP               16595.0
# 1  WOODTRUST FC                     5335.0
# 2  NORTHWEST INV CORP              15830.0
# 3  AMALGAMATED INV CO                903.0
# 4  BANK MGMT                        5486.0

# %%
strings = list(df.dtypes[df.dtypes == 'object'].index)
strings
# Out:
# ['Originating_Lender',
#  'Originating_Lender_City',
#  'Originating_Lender_State',
#  'Name_HCR',
#  'NM_LGL',
#  'NM_Short']

# %%
for col in strings:
    df[col] = df[col].str.upper()

# %%
df.head()
# Out:
#      RSSDHCR              Originating_Lender Originating_Lender_City  \
# 0  1020395.0              CCB COMMUNITY BANK               ANDALUSIA
# 1  1020582.0                  WOODTRUST BANK        WISCONSIN RAPIDS
# 2  1020667.0  NORTHWEST BANK & TRUST COMPANY               DAVENPORT
# 3  1020676.0     AMALGAMATED BANK OF CHICAGO                 CHICAGO
# 4  1020854.0           FIRSTBANK OF NEBRASKA                   WAHOO
#
#    Originating_Lender_Location_ID Originating_Lender_State  \
# 0                            26.0                       AL
# 1                         77051.0                       WI
# 2                         24824.0                       IA
# 3                         20494.0                       IL
# 4                         42693.0                       NE
#
#    Current_Approval_Amount  Forgiveness_Amount  Forgivness_Pct  \
# 0              21420366.01         21224047.72        0.990835
# 1              31543689.32         31834545.84        1.009221
# 2              26963725.00         26824637.15        0.994842
# 3               3049177.89          3036048.99        0.995694
# 4              10426743.02         10401369.48        0.997566
#
#                      Name_HCR   UNINUM  \
# 0      SOUTHERN NATIONAL CORP  10739.0
# 1    WOODTRUST FINANCIAL CORP   3599.0
# 2   NORTHWEST INVESTMENT CORP  10071.0
# 3  AMALGAMATED INVESTMENTS CO    581.0
# 4         BANK MANAGEMENT INC   3718.0
#
#                                               NM_LGL  \
# 0  SOUTHERN NATIONAL CORPORATION                 ...
# 1  WOODTRUST FINANCIAL CORPORATION               ...
# 2  NORTHWEST INVESTMENT CORP.                    ...
# 3  AMALGAMATED INVESTMENTS COMPANY               ...
# 4  BANK MANAGEMENT, INC.                         ...
#
#                          NM_Short     Cert
# 0  SOUTHERN NAT CORP               16595.0
# 1  WOODTRUST FC                     5335.0
# 2  NORTHWEST INV CORP              15830.0
# 3  AMALGAMATED INV CO                903.0
# 4  BANK MGMT                        5486.0

# %%
df.isnull().sum()
# Out:
# RSSDHCR                           1996
# Originating_Lender                   0
# Originating_Lender_City              0
# Originating_Lender_Location_ID       0
# Originating_Lender_State             0
# Current_Approval_Amount              0
# Forgiveness_Amount                   0
# Forgivness_Pct                       0
# Name_HCR                          1996
# UNINUM                            1996
# NM_LGL                            2073
# NM_Short                          2073
# Cert                              1443
# dtype: int64

# %%
# Fill any remaining nulls with "Not Available" - only for string columns
for col in strings:
    df[col] = df[col].fillna('Not Available')

# %%
df.head()
# Out:
#      RSSDHCR              Originating_Lender Originating_Lender_City  \
# 0  1020395.0              CCB COMMUNITY BANK               ANDALUSIA
# 1  1020582.0                  WOODTRUST BANK        WISCONSIN RAPIDS
# 2  1020667.0  NORTHWEST BANK & TRUST COMPANY               DAVENPORT
# 3  1020676.0     AMALGAMATED BANK OF CHICAGO                 CHICAGO
# 4  1020854.0           FIRSTBANK OF NEBRASKA                   WAHOO
#
#    Originating_Lender_Location_ID Originating_Lender_State  \
# 0                            26.0                       AL
# 1                         77051.0                       WI
# 2                         24824.0                       IA
# 3                         20494.0                       IL
# 4                         42693.0                       NE
#
#    Current_Approval_Amount  Forgiveness_Amount  Forgivness_Pct  \
# 0              21420366.01         21224047.72        0.990835
# 1              31543689.32         31834545.84        1.009221
# 2              26963725.00         26824637.15        0.994842
# 3               3049177.89          3036048.99        0.995694
# 4              10426743.02         10401369.48        0.997566
#
#                      Name_HCR   UNINUM  \
# 0      SOUTHERN NATIONAL CORP  10739.0
# 1    WOODTRUST FINANCIAL CORP   3599.0
# 2   NORTHWEST INVESTMENT CORP  10071.0
# 3  AMALGAMATED INVESTMENTS CO    581.0
# 4         BANK MANAGEMENT INC   3718.0
#
#                                               NM_LGL  \
# 0  SOUTHERN NATIONAL CORPORATION                 ...
# 1  WOODTRUST FINANCIAL CORPORATION               ...
# 2  NORTHWEST INVESTMENT CORP.                    ...
# 3  AMALGAMATED INVESTMENTS COMPANY               ...
# 4  BANK MANAGEMENT, INC.                         ...
#
#                          NM_Short     Cert
# 0  SOUTHERN NAT CORP               16595.0
# 1  WOODTRUST FC                     5335.0
# 2  NORTHWEST INV CORP              15830.0
# 3  AMALGAMATED INV CO                903.0
# 4  BANK MGMT                        5486.0

# %%
df.to_csv('../data/cleaned/lender_data/lender_data.csv', encoding="utf-8")
